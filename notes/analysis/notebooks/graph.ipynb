# %%
import dash
from dash.dependencies import Input, Output
import dash_core_components as dcc
import dash_html_components as html

from pandas_datareader import data as web
from datetime import datetime as dt

app = dash.Dash('Hello World')

app.layout = html.Div([
    dcc.Dropdown(
        id='my-dropdown',
        options=[
            {'label': 'Coke', 'value': 'COKE'},
            {'label': 'Tesla', 'value': 'TSLA'},
            {'label': 'Apple', 'value': 'AAPL'}
        ],
        value='COKE'
    ),
    dcc.Graph(id='my-graph')
], style={'width': '500'})

@app.callback(Output('my-graph', 'figure'), [Input('my-dropdown', 'value')])
def update_graph(selected_dropdown_value):
    df = web.DataReader(
        selected_dropdown_value,
        'google',
        dt(2017, 1, 1),
        dt.now()
    )
    return {
        'data': [{
            'x': df.index,
            'y': df.Close
        }],
        'layout': {'margin': {'l': 40, 'r': 0, 't': 20, 'b': 30}}
    }

app.css.append_css({'external_url': 'https://codepen.io/chriddyp/pen/bWLwgP.css'})

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "Hello World" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "GET /_dash-component-suites/dash_renderer/polyfill@7.v1_8_2m1603457651.8.7.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "GET /_dash-component-suites/dash_renderer/react@16.v1_8_2m1603457651.13.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "GET /_dash-component-suites/dash_renderer/prop-types@15.v1_8_2m1603457651.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "GET /_dash-component-suites/dash_renderer/react-dom@16.v1_8_2m1603457651.13.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "GET /_dash-component-suites/dash_html_components/dash_html_components.v1_1_1m1603457652.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "GET /_dash-component-suites/dash_core_components/dash_core_components-shared.v1_12_1m1603457651.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "GET /_dash-component-suites/dash_core_components/dash_core_components.v1_12_1m1603457651.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "GET /_dash-component-suites/dash_renderer/dash_renderer.v1_8_2m1603457651.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "GET /_dash-component-suites/dash_core_components/async-graph.v1_12_1m1600286997.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "GET /_dash-component-suites/dash_core_components/async-dropdown.v1_12_1m1600286997.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "GET /_favicon.ico?v=1.16.3 HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1072, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-1-065c35a9e866>", line 26, in update_graph
#     df = web.DataReader(
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 373, in DataReader
#     raise NotImplementedError(msg)
# NotImplementedError: data_source='google' is not implemented
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [23/Oct/2020 15:54:43] "GET /_dash-component-suites/dash_core_components/async-plotlyjs.v1_12_1m1600286997.js HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1072, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-1-065c35a9e866>", line 26, in update_graph
#     df = web.DataReader(
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 373, in DataReader
#     raise NotImplementedError(msg)
# NotImplementedError: data_source='google' is not implemented
# 127.0.0.1 - - [23/Oct/2020 15:54:50] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [23/Oct/2020 15:55:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:55:01] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:55:01] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2020 15:55:01] "GET /_favicon.ico?v=1.16.3 HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1072, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-1-065c35a9e866>", line 26, in update_graph
#     df = web.DataReader(
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 373, in DataReader
#     raise NotImplementedError(msg)
# NotImplementedError: data_source='google' is not implemented
# 127.0.0.1 - - [23/Oct/2020 15:55:01] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1072, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-1-065c35a9e866>", line 26, in update_graph
#     df = web.DataReader(
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/evgeniyskuratov/opt/anaconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 373, in DataReader
#     raise NotImplementedError(msg)
# NotImplementedError: data_source='google' is not implemented
# 127.0.0.1 - - [23/Oct/2020 15:55:10] "POST /_dash-update-component HTTP/1.1" 500 -
